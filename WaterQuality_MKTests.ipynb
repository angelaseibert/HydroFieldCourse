# %% [markdown]
# # Mann Kendall Tests

# %%
# load libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pymannkendall as mk

# %%
# print working directory
pwd
# Out:
# 'C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro'

# %%
# load csv as dataframe and print
WQ_df = pd.read_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\Water_Quality_Data.csv')
WQ_df
# Out:
#     SampleID       Date   Time  Site_Information Site_Location  Temp_C     EC  \
# 0         UC  2/24/2023  10:36  Below Confluence         Upper     1.3  150.8
# 1         LC  2/24/2023  10:16  Below Confluence         Lower     7.2  131.5
# 2         UM  2/24/2023  10:44      Main Channel         Upper     4.3  171.3
# 3         LM  2/24/2023  10:23      Main Channel         Lower     3.8  151.7
# 4        UP1  2/24/2023  10:43              Pool         Upper     4.7  171.3
# ..       ...        ...    ...               ...           ...     ...    ...
# 994      NaN        NaN    NaN               NaN           NaN     NaN    NaN
# 995      NaN        NaN    NaN               NaN           NaN     NaN    NaN
# 996      NaN        NaN    NaN               NaN           NaN     NaN    NaN
# 997      NaN        NaN    NaN               NaN           NaN     NaN    NaN
# 998      NaN        NaN    NaN               NaN           NaN     NaN    NaN
#
# ...

# %%
# filter df by upper and lower dam
WQ_df_upper = WQ_df[WQ_df['Site_Location'] == 'Upper']
WQ_df_lower = WQ_df[WQ_df['Site_Location'] == 'Lower']

# %%
# filter by feature
WQ_df_upper_BC = WQ_df_upper[WQ_df_upper['Site_Information'] == 'Below Confluence']
WQ_df_upper_MC = WQ_df_upper[WQ_df_upper['Site_Information'] == 'Main Channel']
WQ_df_upper_P = WQ_df_upper[WQ_df_upper['Site_Information'] == 'Pool']
WQ_df_upper_SC = WQ_df_upper[WQ_df_upper['Site_Information'] == 'Side Channel']

WQ_df_lower_BC = WQ_df_lower[WQ_df_lower['Site_Information'] == 'Below Confluence']
WQ_df_lower_MC = WQ_df_lower[WQ_df_lower['Site_Information'] == 'Main Channel']
WQ_df_lower_P = WQ_df_lower[WQ_df_lower['Site_Information'] == 'Pool']
WQ_df_lower_SC = WQ_df_lower[WQ_df_lower['Site_Information'] == 'Side Channel']

# %% [markdown]
# # Save files as csvs filtered by date and metric of interest

# %%
# upper feature and temp

upper_MK_TempBC_dfs = WQ_df_upper_BC[['Date', 'Temp_C']]
upper_MK_TempBC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_TempBC.csv', index = False)

upper_MK_TempMC_dfs = WQ_df_upper_MC[['Date', 'Temp_C']]
upper_MK_TempMC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_TempMC.csv', index = False)

upper_MK_TempP_dfs = WQ_df_upper_P[['Date', 'Temp_C']]
upper_MK_TempP_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_TempP.csv', index = False)

upper_MK_TempSC_dfs = WQ_df_upper_SC[['Date', 'Temp_C']]
upper_MK_TempSC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_TempSC.csv', index = False)

# upper feature and EC

upper_MK_ECBC_dfs = WQ_df_upper_BC[['Date', 'EC']]
upper_MK_ECBC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_ECBC.csv', index = False)

upper_MK_ECMC_dfs = WQ_df_upper_MC[['Date', 'EC']]
upper_MK_ECMC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_ECMC.csv', index = False)

upper_MK_ECP_dfs = WQ_df_upper_P[['Date', 'EC']]
upper_MK_ECP_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_ECP.csv', index = False)

upper_MK_ECSC_dfs = WQ_df_upper_SC[['Date', 'EC']]
upper_MK_ECSC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_ECSC.csv', index = False)


# upper feature and NOx

upper_MK_NOxBC_dfs = WQ_df_upper_BC[['Date', 'NOx_mgL']]
upper_MK_NOxBC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_NOxBC.csv', index = False)

upper_MK_NOxMC_dfs = WQ_df_upper_MC[['Date', 'NOx_mgL']]
upper_MK_NOxMC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_NOxMC.csv', index = False)

upper_MK_NOxP_dfs = WQ_df_upper_P[['Date', 'NOx_mgL']]
upper_MK_NOxP_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_NOxP.csv', index = False)

upper_MK_NOxSC_dfs = WQ_df_upper_SC[['Date', 'NOx_mgL']]
upper_MK_NOxSC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_NOxSC.csv', index = False)

# upper feature and PO4

upper_MK_PO4BC_dfs = WQ_df_upper_BC[['Date', 'PO4_mgL']]
upper_MK_PO4BC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_PO4BC.csv', index = False)

upper_MK_PO4MC_dfs = WQ_df_upper_MC[['Date', 'PO4_mgL']]
upper_MK_PO4MC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_PO4MC.csv', index = False)

upper_MK_PO4P_dfs = WQ_df_upper_P[['Date', 'PO4_mgL']]
upper_MK_PO4P_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_PO4P.csv', index = False)

upper_MK_PO4SC_dfs = WQ_df_upper_SC[['Date', 'PO4_mgL']]
upper_MK_PO4SC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_PO4SC.csv', index = False)

# upper feature and NH

upper_MK_NH4BC_dfs = WQ_df_upper_BC[['Date', 'NH4']]
upper_MK_NH4BC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_NH4BC.csv', index = False)

upper_MK_NH4MC_dfs = WQ_df_upper_MC[['Date', 'NH4']]
upper_MK_NH4MC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_NH4MC.csv', index = False)

upper_MK_NH4P_dfs = WQ_df_upper_P[['Date', 'NH4']]
upper_MK_NH4P_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_NH4P.csv', index = False)

upper_MK_NH4SC_dfs = WQ_df_upper_SC[['Date', 'NH4']]
upper_MK_NH4SC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\upper_MK_NH4SC.csv', index = False)

# %%
# lower feature and temp

lower_MK_TempBC_dfs = WQ_df_lower_BC[['Date', 'Temp_C']]
lower_MK_TempBC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_TempBC.csv', index = False)

lower_MK_TempMC_dfs = WQ_df_lower_MC[['Date', 'Temp_C']]
lower_MK_TempMC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_TempMC.csv', index = False)

lower_MK_TempP_dfs = WQ_df_lower_P[['Date', 'Temp_C']]
lower_MK_TempP_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_TempP.csv', index = False)

lower_MK_TempSC_dfs = WQ_df_lower_SC[['Date', 'Temp_C']]
lower_MK_TempSC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_TempSC.csv', index = False)

# lower feature and EC

lower_MK_ECBC_dfs = WQ_df_lower_BC[['Date', 'EC']]
lower_MK_ECBC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_ECBC.csv', index = False)

lower_MK_ECMC_dfs = WQ_df_lower_MC[['Date', 'EC']]
lower_MK_ECMC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_ECMC.csv', index = False)

lower_MK_ECP_dfs = WQ_df_lower_P[['Date', 'EC']]
lower_MK_ECP_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_ECP.csv', index = False)

lower_MK_ECSC_dfs = WQ_df_lower_SC[['Date', 'EC']]
lower_MK_ECSC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_ECSC.csv', index = False)


# lower feature and NOx

lower_MK_NOxBC_dfs = WQ_df_lower_BC[['Date', 'NOx_mgL']]
lower_MK_NOxBC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_NOxBC.csv', index = False)

lower_MK_NOxMC_dfs = WQ_df_lower_MC[['Date', 'NOx_mgL']]
lower_MK_NOxMC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_NOxMC.csv', index = False)

lower_MK_NOxP_dfs = WQ_df_lower_P[['Date', 'NOx_mgL']]
lower_MK_NOxP_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_NOxP.csv', index = False)

lower_MK_NOxSC_dfs = WQ_df_lower_SC[['Date', 'NOx_mgL']]
lower_MK_NOxSC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_NOxSC.csv', index = False)

# lower feature and PO4

lower_MK_PO4BC_dfs = WQ_df_lower_BC[['Date', 'PO4_mgL']]
lower_MK_PO4BC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_PO4BC.csv', index = False)

lower_MK_PO4MC_dfs = WQ_df_lower_MC[['Date', 'PO4_mgL']]
lower_MK_PO4MC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_PO4MC.csv', index = False)

lower_MK_PO4P_dfs = WQ_df_lower_P[['Date', 'PO4_mgL']]
lower_MK_PO4P_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_PO4P.csv', index = False)

lower_MK_PO4SC_dfs = WQ_df_lower_SC[['Date', 'PO4_mgL']]
lower_MK_PO4SC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_PO4SC.csv', index = False)

# lower feature and NH

lower_MK_NH4BC_dfs = WQ_df_lower_BC[['Date', 'NH4']]
lower_MK_NH4BC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_NH4BC.csv', index = False)

lower_MK_NH4MC_dfs = WQ_df_lower_MC[['Date', 'NH4']]
lower_MK_NH4MC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_NH4MC.csv', index = False)

lower_MK_NH4P_dfs = WQ_df_lower_P[['Date', 'NH4']]
lower_MK_NH4P_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_NH4P.csv', index = False)

lower_MK_NH4SC_dfs = WQ_df_lower_SC[['Date', 'NH4']]
lower_MK_NH4SC_dfs.to_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\lower_MK_NH4SC.csv', index = False)

# %% [markdown]
# # Run MK tests

# %%
# read csv files for each dam feature filtered to metric of interest for either upper or lower dam
MK_test_SC = pd.read_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\MK_files\\lower_MK_ECSC.csv', parse_dates = ['Date'],index_col='Date')
MK_test_P = pd.read_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\MK_files\\lower_MK_ECP.csv', parse_dates=['Date'],index_col='Date')
MK_test_MC = pd.read_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\MK_files\\lower_MK_ECMC.csv', parse_dates=['Date'],index_col='Date')
MK_test_BC = pd.read_csv('C:\\Users\\ANGELASEIBERT\\Desktop\\Hydro\\MK_files\\lower_MK_ECBC.csv', parse_dates=['Date'],index_col='Date')

mkresult_SC = mk.pre_whitening_modification_test(MK_test_SC)
print('Side Channel:', mkresult_SC)

mkresult_P = mk.pre_whitening_modification_test(MK_test_P)
print('Pool:', mkresult_P)

mkresult_MC = mk.pre_whitening_modification_test(MK_test_MC)
print('Main Channel:', mkresult_MC)

mkresult_BC = mk.pre_whitening_modification_test(MK_test_BC)
print('Below Confluence:', mkresult_BC)
# Out:
# Side Channel: Modified_Mann_Kendall_Test_PreWhitening_Approach(trend='no trend', h=False, p=1.0, z=0.0, Tau=-1.0, s=-1.0, var_s=1.0, slope=2.6500000000000057, intercept=152.25)
# Pool: Modified_Mann_Kendall_Test_PreWhitening_Approach(trend='no trend', h=False, p=1.0, z=0.0, Tau=-0.03571428571428571, s=-1.0, var_s=64.33333333333333, slope=0.343750000000003, intercept=153.025)
# Main Channel: Modified_Mann_Kendall_Test_PreWhitening_Approach(trend='no trend', h=False, p=1.0, z=0.0, Tau=-1.0, s=-1.0, var_s=1.0, slope=1.4000000000000057, intercept=153.1)
# Below Confluence: Modified_Mann_Kendall_Test_PreWhitening_Approach(trend='no trend', h=False, p=1.0, z=0.0, Tau=1.0, s=1.0, var_s=1.0, slope=12.299999999999997, intercept=143.8)
